# %% [markdown]
# # ⛰ ***Exercícios — Aula 4***

# %% [markdown]
# ## Questão 1 📝
#
# Implemente uma classe `Pessoa` que represente uma pessoa com nome e idade.
#
# A classe deve possuir um método `apresentar()` que retorne uma string com a apresentação da pessoa no formato:
#
# ```
# Olá, meu nome é Davi e tenho 22 anos.
# ```

# %%
class Pessoa:
    def __init__(self, nome, idade):
        self.nome = nome
        self.idade = idade

    def apresentar(self):
        return f"Olá, o meu nome é {self.nome}e tenho {self.idade} anos"

pessoa = Pessoa("Camila", 18)

print(pessoa.apresentar())
# Out:
# Olá, o meu nome é Camilae tenho 18 anos

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *Use `__init__` para inicializar os atributos e `self` para acessá-los dentro dos métodos.*

# %% [markdown]
# ## Questão 2 📝
#
# Crie uma classe `Produto` com os atributos `nome` e `preco`.
#
# Implemente um método `aplicar_desconto(percentual)` que reduza o preço do produto conforme o percentual informado.
#
# O método deve rejeitar percentuais fora do intervalo 0–100.

# %%
class Produto:
    def __init__(self, nome, preco):
        self.nome = nome
        self.preco = preco

    def aplicar_desconto(self, percentual):

        if percentual >= 0 and percentual <= 100:
            self.preco -= self.preco * (percentual/100)
            return self.preco
        else:
            raise ValueError("O desconto não pode ser negativo e nem maior que 100%!")

produto = Produto("Livro", 180)
print(produto.preco)
produto.aplicar_desconto(80)
print(produto.preco)
# Out:
# 180
# 36.0

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# *Valide o percentual antes de aplicar qualquer cálculo. Use `raise ValueError` para sinalizar entradas inválidas.*

# %% [markdown]
# ## Questão 3 📝
#
# Implemente uma classe `ContaBancaria` com operações de depósito, saque e consulta de saldo.
#
# O saldo **não deve ser acessado diretamente** de fora da classe.

# %%
class ContaBancaria:
    def __init__(self, saldo_inicial):
        self.saldo = saldo_inicial

    def depositar(self, valor):
        if valor > 0:
            self.saldo += valor
            print(f"O valor de R${valor} foi depositado com sucesso")

        else:
            raise ValueError("Não é possível depositar um valor negativo ou um valor nulo")
        
    def resgatar(self, valor):
        if valor > 0 and valor <= self.saldo:
            self.saldo -= valor
            print(f"O valor R${valor} foi resgatado com sucesso")

        else:
            raise ValueError("Não é possível resgatar um valor maior do que o saldo atual")
        
    def consultar(self):
        print(f"Saldo atual: R${self.saldo}")

conta_bancaria = ContaBancaria(saldo_inicial = 2000)
conta_bancaria.depositar(200)
conta_bancaria.consultar()
conta_bancaria.resgatar(1000)
conta_bancaria.consultar()
# Out:
# O valor de R$200 foi depositado com sucesso
# Saldo atual: R$2200
# O valor R$1000 foi resgatado com sucesso
# Saldo atual: R$1200

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# Em Python, o prefixo `_` em um atributo (ex: `_saldo`) indica que ele é de uso interno — é uma convenção de encapsulamento.
#
# Pense nas validações: faz sentido depositar um valor negativo? Sacar mais do que tem?

# %% [markdown]
# ## Questão 4 📝
#
# Crie uma classe `Livro` que controle o progresso de leitura.
#
# A classe deve ter `titulo` e `paginas` (total), e um método `ler(qtd)` que avance as páginas lidas. Não permita que as páginas lidas ultrapassem o total.
#
# Implemente também um método `progresso()` que retorne o percentual lido.

# %%
class Livro:
    def __init__(self, titulo, paginas_total):

        if paginas_total <= 0:
            raise ValueError("O livro precisa ter no mínimo uma página")
        self.titulo = titulo
        self.paginas_total = paginas_total
        self.paginas_lidas = 0

    def ler(self,qtde):

        if qtde <= 0:
            raise ValueError("Não existe um número negativo de páginas!")

        self.paginas_lidas += qtde 

        if self.paginas_lidas > self.paginas_total:
            self.paginas_lidas = self.paginas_total

            

    def progresso(self):
        percentual = (self.paginas_lidas/self.paginas_total)*100
        print(f'A leitura está {percentual:.2f}% completa')

liv = Livro("Batman: The Long Halloween", 407)
    
print("Livro:", liv.titulo)
print("Páginas:", liv.paginas_total)
liv.ler(200)
print("Quantidade de páginas lidas: ", liv.paginas_lidas)
liv.progresso()
# Out:
# Livro: Batman: The Long Halloween
# Páginas: 407
# Quantidade de páginas lidas:  200
# A leitura está 49.14% completa

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# Guarde as páginas já lidas como um atributo separado, iniciado em zero.
#
# Porcentagem = `(paginas_lidas / paginas_total) * 100`.

# %% [markdown]
# ## Questão 5 📝
#
# Crie uma hierarquia de classes para funcionários.
#
# - `Funcionario(nome, salario_base)` — método `calcular_salario()` retorna o salário base
# - `Gerente` — herda de `Funcionario` e adiciona R$ 1.000 ao salário
# - `Vendedor(nome, salario_base, vendas)` — herda de `Funcionario` e adiciona 10% do valor de vendas
#
# Instancie um `Gerente` e um `Vendedor` e imprima o salário de cada um.

# %%
class Funcionario:
    def __init__(self, nome, salario_base):
        self.nome = nome
        self.salario_base = salario_base

    def calcular_salario(self):
        return self.salario_base
    
class Gerente(Funcionario):
    def calcular_salario(self):
        return self.salario_base + 1000

class Vendedor(Funcionario):
    def __init__(self, nome, salario_base, vendas):
        super().__init__(nome, salario_base)
        self.vendas = vendas
    def calcular_salario(self):
        return self.salario_base + (self.vendas*0.1)
    
gerente = Gerente("Camila", 3000)
vendedor = Vendedor("Mila", 3000, 6000)
print(gerente.calcular_salario())
print(vendedor.calcular_salario())
# Out:
# 4000
# 3600.0

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# Herança: `class Filha(Pai)`. A subclasse pode **sobrescrever** métodos do pai simplesmente redefinindo-os.
#
# Quando a subclasse tem atributos extras (como `vendas`), use `super().__init__(...)` para reaproveitar o `__init__` da classe pai.

# %% [markdown]
# ## Questão 6 📝
#
# Implemente um sistema de pagamentos usando polimorfismo.
#
# Crie uma classe base `Pagamento` com um método `processar()`, e duas subclasses: `Pix` e `Cartao`, cada uma com sua própria implementação do método.
#
# Ao final, crie uma lista com um objeto de cada tipo e chame `processar()` para todos.

# %%
class Pagamento:
    def __init__(self, valor):
        self.valor = valor
        

class Pix(Pagamento):
    def processar(self):
        print(f"Processando o pagamento de R${self.valor} por pix...")

class Cartao(Pagamento):
    def processar(self):
        print(f"Processando o pagamento de R${self.valor} por cartão...")


pix = Pix(30)
pix.processar()
cartao = Cartao(100)
cartao.processar()
# Out:
# Processando o pagamento de R$30 por pix...
# Processando o pagamento de R$100 por cartão...

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# Polimorfismo = mesma interface (`processar()`), comportamentos diferentes por classe.
#
# Iterar sobre uma lista de objetos e chamar o mesmo método em cada um é a aplicação clássica — o Python resolve qual implementação usar automaticamente.

# %% [markdown]
# ## Questão 7 📝
#
# Crie uma classe `Carrinho` que permita:
# - `adicionar_produto(nome, preco)` — adiciona um produto ao carrinho
# - `remover_produto(nome)` — remove um produto pelo nome
# - `total()` — retorna o valor total dos produtos no carrinho

# %%
class Carrinho:
    def __init__(self):
        self.produtos = []

    def adicionar_produto(self, nome, preco):
        self.produtos.append((nome, preco))

    def remover_produto(self, nome, preco):
        self.produtos.remove((nome, preco))

    def total(self):
        for produto in self.produtos:
            total = sum(produto[1] for produto in self.produtos)
            return total

carrinho = Carrinho()
carrinho.adicionar_produto("Livro", 30)
carrinho.adicionar_produto("Bolo de chocolate", 25)
print(carrinho.total())
carrinho.remover_produto("Bolo de chocolate", 25)
print(carrinho.total())
# Out:
# 55
# 30

# %% [markdown]
# ### 💡 Dica:
#
# *Utilize somente se necessário — tente resolver primeiro sozinho!*

# %% [markdown]
# Use uma lista para armazenar os produtos. Tuplas `(nome, preco)` funcionam bem aqui.
#
# `sum()` com um generator expression é uma forma elegante de somar os preços.
